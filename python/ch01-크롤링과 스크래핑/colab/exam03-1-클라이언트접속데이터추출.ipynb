# %%
import urllib.request

url = "http://api.aoikujira.com/ip/ini"

res = urllib.request.urlopen(url)
data = res.read()
#data = urllib.request.urlopen(url).read() 메소드 체이닝
text = data.decode("utf-8") #한글이 깨지지 않도록
#text=urllib.request.urlopen(url).read().decode("utf-8") 메소드 체이닝으로 3줄의 코드가 한 줄로 줄어들 수 있음

print(text)
# Out:
# <pre>[ip]
# API_URI=http://api.aoikujira.com/ip/get.php
# REMOTE_ADDR=34.74.189.39
# REMOTE_HOST=39.189.74.34.bc.googleusercontent.com
# REMOTE_PORT=58890
# HTTP_HOST=api.aoikujira.com
# HTTP_USER_AGENT=Python-urllib/3.12
# HTTP_ACCEPT_LANGUAGE=
# HTTP_ACCEPT_CHARSET=
# SERVER_PORT=80
# FORMAT=ini
