# %%
#강의 코드
import urllib.request

url = "http://uta.pw/shodou/img/28/214.png"
savename = "test.png"

urllib.request.urlretrieve(url, savename)
#다른 홈페이지의 로고도 가져올 수 있음. 요즘은 png 확장자 잘 안 써서 로고 가져오기 어렵긴 함.

print("===== 저장되었습니다.")
# Out:
# ===== 저장되었습니다.
