# %% [markdown]
# ### 파이썬 크롤링
# > 데이터를 자동으로 저장하는 실습을 위해, 크롤링 기술을 활용<br>
# > 파이썬 입문과 크롤링 학습에서 익힌 크롤링 기술을 활용

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.card-body')
    for item in data:
        category = item.select_one('h2.card-title').get_text().replace('관련 상품 추천', '').strip()
        product = item.select_one('h4.card-text').get_text().replace('상품명:', '').strip()
        print (category, product)

# %% [markdown]
# ### Schema 구성 (필요 없음)

# %% [markdown]
# ### 크롤링 + MongoDB 저장

# %%
import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient


client = MongoClient("mongodb://localhost:27017")
db = client['test']
collection = db.daveshop

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.card-body')
    for item in data:
        category = item.select_one('h2.card-title').get_text().replace('관련 상품 추천', '').strip()
        product = item.select_one('h4.card-text').get_text().replace('상품명:', '').strip()
        data = dict()
        data['category'] = category
        data['product'] = product
        collection.insert_one(data)
        
client.close()

# %% [markdown]
# ### MongoDB 데이터 읽기

# %%
from pymongo import MongoClient

# MongoDB에 연결 (인증 미필요시)
client = MongoClient("mongodb://localhost:27017")

db = client['test']
collection = db.daveshop

documents = collection.find()  
for document in documents:
    print(document)

client.close()

# %% [markdown]
# ### 연습문제를 위한 사전 준비

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")

db = client['test']
collection = db.daveshop

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 'category' 필드에 있는 모든 카테고리 종류를 조회하세요 (중복제거)</font><br>
# </div>

# %%
category = collection.distinct("category")
print(category)
# Out:
# ['매트리스커버', '여름이불세트', '행거도어']

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 모든 상품(product)을 조회하세요</font><br>
# </div>

# %%
products = collection.find({},{"_id":0, "product":1})
for product in products: print(product)

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: "매트리스커버" 카테고리의 모든 상품을 조회하세요<br> (find 와 aggregation 을 사용한 코드를 각각 작성해주세요)</font><br>
# </div>

# %%
for item in collection.find({"category":{"$eq": "매트리스커버"}},{"_id":0, "product":1}): print(item)

# %%
pipeline = [
    {"$match": {"category": { "$eq": "매트리스커버"}}},
    {"$project": {"_id":0, "product":1}}
]
for item in collection.aggregate(pipeline): print(item)

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 각 카테고리별 상품 수를 조회하세요. 이를 위해 MongoDB의 aggregation 기능을 사용하세요</font><br>
# </div>

# %%
pipeline=[
    {"$group": {"_id": "$category", "count": {"$sum":1}}},
    {"$project": {"_id":0, "카테고리":"$_id", "상품 수":"$count"}}
]
for item in collection.aggregate(pipeline): print(item)
# Out:
# {'카테고리': '여름이불세트', '상품 수': 31}
# {'카테고리': '매트리스커버', '상품 수': 31}
# {'카테고리': '행거도어', '상품 수': 32}

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 상품명(product)에 '핑크'가 포함된 모든 상품을 조회하세요</font><br>
# </div>

# %%
import re

regux = re.compile("핑크")

for item in collection.find({"product":regux}, {"_id":0, "상품명: ":"$product"}):
    print(item)
# Out:
# {'상품명: ': '보드래 헬로우 누빔 매트리스커버, 핑크'}
# {'상품명: ': '보드래 퍼펙트 누빔 매트리스커버, 베이지핑크'}
# {'상품명: ': '쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크'}
# {'상품명: ': '보드래 헬로우 누빔 매트리스커버, 핑크'}
# {'상품명: ': '더자리 에코항균 마이크로 매트리스커버, 밀키핑크'}

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: '매트리스커버' 카테고리의 상품 중, 상품명에 '차콜'이 포함된 상품을 조회하세요</font><br>
# </div>

# %%
import re

getColor = re.compile("차콜")

for item in collection.find({"$and": [{"category": {"$eq": "매트리스커버"}}, {"product": getColor}]},
                           {"_id":0, "상품명": "$product"}):
    print(item)
# Out:
# {'상품명': '보드래 퍼펙트 누빔 매트리스커버, 차콜'}
# {'상품명': '더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이'}
# {'상품명': '더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이'}
# {'상품명': '바숨 순면 누빔 침대 매트리스커버, 차콜'}
# {'상품명': '쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이'}

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 'product' 필드에 대한 텍스트 인덱스를 생성하세요</font><br>
# </div>

# %%
result = collection.create_index([("product","text")])
print(result)
# Out:
# product_text

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1565C0;background-color:#E3F2FD;padding:10px">
# <font size="3em" style="color:#0D47A1;">연습문제: 'product' 필드에서 '누빔'이라는 단어를 포함하는 모든 문서를 텍스트 검색을 이용해 찾으세요<br> (find 와 aggregation 을 사용한 코드를 각각 작성해주세요)</font><br>
# </div>

# %%
for item in collection.find({"$text": {"$search": "누빔"}}, {"_id":0, "상품명": "$product"}):
    print(item)
# Out:
# {'상품명': '보드래 헬로우 누빔 매트리스커버, 핑크'}
# {'상품명': '보드래 퍼펙트 누빔 매트리스커버, 베이지핑크'}
# {'상품명': '보드래 퍼펙트 누빔 매트리스커버, 차콜'}
# {'상품명': '보드래 헬로우 누빔 매트리스커버, 핑크'}
# {'상품명': '바숨 순면 누빔 침대 매트리스커버, 화이트'}
# {'상품명': '바숨 순면 누빔 침대 매트리스커버, 차콜'}
# {'상품명': '보드래 국내산 순면 60수 누빔 매트리스커버, 그레이'}
# {'상품명': '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고'}
# {'상품명': '스코홈 어번시리즈 순면 차렵이불 누빔 매트커버세트 S 차콜'}
# {'상품명': '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독'}
# {'상품명': '타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑'}
# {'상품명': '쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜'}

# %%
pipeline = [
    {"$match": {"product": {"$in": "누빔" } } },
    {"$project": {"_id":0, "상품명":"$product"}}
]
for item in collection.aggregate(pipeline): print(item)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[53], line 5
#       1 pipeline = [
#       2     {"$match": {"$product": {"$in": "누빔" } } },
#       3     {"$project": {"_id":0, "상품명":"$product"}}
#       4 ]
# ----> 5 for item in collection.aggregate(pipeline): print(item)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/collection.py:3010, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2924 """Perform an aggregation using the aggregation framework on this
#    2925 collection.
#    2926
#    (...)   3007     https://mongodb.com/docs/manual/reference/command/aggregate
#    3008 """
#    3009 with self._database.client._tmp_session(session) as s:
# -> 3010     return self._aggregate(
#    3011         _CollectionAggregationCommand,
#    3012         pipeline,
#    3013         CommandCursor,
#    3014         session=s,
#    3015         let=let,
#    3016         comment=comment,
#    3017         **kwargs,
#    3018     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/collection.py:2908, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, let, comment, **kwargs)
#    2898     kwargs["comment"] = comment
#    2899 cmd = aggregation_command(
#    2900     self,
#    2901     cursor_class,
#    (...)   2905     user_fields={"cursor": {"firstBatch": 1}},
#    2906 )
# -> 2908 return self._database.client._retryable_read(
#    2909     cmd.get_cursor,
#    2910     cmd.get_read_preference(session),  # type: ignore[arg-type]
#    2911     session,
#    2912     retryable=not cmd._performs_write,
#    2913     operation=_Op.AGGREGATE,
#    2914 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2048, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
#    2047 with self._tmp_session(session) as s:
# -> 2048     return self._retry_internal(
#    2049         func,
#    2050         s,
#    2051         None,
#    2052         operation,
#    2053         is_read=True,
#    2054         address=address,
#    2055         read_pref=read_pref,
#    2056         retryable=retryable,
#    2057         operation_id=operation_id,
#    2058     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2924, in _ClientConnectionRetryable._read(self)
#    2916 if self._retrying:
#    2917     _debug_log(
#    2918         _COMMAND_LOGGER,
#    2919         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   2922         operationId=self._operation_id,
#    2923     )
# -> 2924 return self._func(self._session, self._server, conn, read_pref)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/aggregation.py:162, in _AggregationCommand.get_cursor(self, session, server, conn, read_preference)
#     159     write_concern = None
#     161 # Run command.
# --> 162 result = conn.command(
#     163     self._database.name,
#     164     cmd,
#     165     read_preference,
#     166     self._target.codec_options,
#     167     parse_write_concern_error=True,
#     168     read_concern=read_concern,
#     169     write_concern=write_concern,
#     170     collation=self._collation,
#     171     session=session,
#     172     client=self._database.client,
#     173     user_fields=self._user_fields,
#     174 )
#     176 if self._result_processor:
#     177     self._result_processor(result, conn)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/pool.py:398, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     396     self._raise_if_not_writable(unacknowledged)
#     397 try:
# --> 398     return command(
#     399         self,
#     400         dbname,
#     401         spec,
#     402         self.is_mongos,
#     403         read_preference,
#     404         codec_options,  # type: ignore[arg-type]
#     405         session,
#     406         client,
#     407         check,
#     408         allowable_errors,
#     409         self.address,
#     410         listeners,
#     411         self.max_bson_size,
#     412         read_concern,
#     413         parse_write_concern_error=parse_write_concern_error,
#     414         collation=collation,
#     415         compression_ctx=self.compression_context,
#     416         use_op_msg=self.op_msg_enabled,
#     417         unacknowledged=unacknowledged,
#     418         user_fields=user_fields,
#     419         exhaust_allowed=exhaust_allowed,
#     420         write_concern=write_concern,
#     421     )
#     422 except (OperationFailure, NotPrimaryError):
#     423     raise
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/synchronous/network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File /opt/anaconda3/lib/python3.13/site-packages/pymongo/helpers_shared.py:284, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 284 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: unknown top level operator: $product. If you have a field name that starts with a '$' symbol, consider using $getField or $setField., full error: {'ok': 0.0, 'errmsg': "unknown top level operator: $product. If you have a field name that starts with a '$' symbol, consider using $getField or $setField.", 'code': 2, 'codeName': 'BadValue'}
